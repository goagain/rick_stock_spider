# %%
import yfinance as yf
msft = yf.Ticker("hitec")

# get stock info
msft.info

# get historical market data
hist = msft.history(period='3mo', interval='1d')

# %%
import matplotlib.pyplot as plot
import mplfinance as mpf
import pandas as pd

mpf.plot(hist, type = 'candle', mav=5 , volume=True)

# %%
hist
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2020-09-02  298.880005  303.600006  ...          0             0
# 2020-09-03  295.989990  297.600006  ...          0             0
# 2020-09-04  287.250000  289.000000  ...          0             0
# 2020-09-08  271.279999  279.299988  ...          0             0
# 2020-09-09  275.769989  278.480011  ...          0             0
# ...                ...         ...  ...        ...           ...
# 2020-11-24  268.489990  277.820007  ...          0             0
# 2020-11-25  278.140015  280.179993  ...          0             0
# 2020-11-27  277.390015  279.130005  ...          0             0
# 2020-11-30  276.029999  277.700012  ...          0             0
# 2020-12-01  279.160004  289.299988  ...          0             0
#
# [63 rows x 7 columns]
